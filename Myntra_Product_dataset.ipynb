# %%
                    # MYNTRA PRODUCT DATASET--2025

# %%
#1. Import necessary modules

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
import time

# %%
# Extracting data

# %%
def search_url(search_term, page_number):
    template = 'https://www.myntra.com/{}?rawQuery={}&p={}'
    return template.format(search_term, search_term, page_number)

driver = webdriver.Chrome()

org_url = input('enter your search term: ')

brands = []
price=[]
original_price=[]
description=[]
ratings=[]
product_url=[]

for i in range(1, 300):
    driver.get(search_url(org_url, i))
    
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    try:
        brand = soup.find_all('h3', class_="product-brand")
        for a in brand:
            brands.append(a.text)
    except AttributeError:
        continue
        
    #price
    try:
        pr = soup.find_all('span',class_="product-discountedPrice")
        for b in pr:
            price.append(float(b.text.strip('Rs. ')))
    except AttributeError:
        price.append(None)
        
    missing_count = len(brands) - len(price)
    if missing_count > 0:
        price.extend([None]*missing_count)
    
    #original price
    try:
        mrp = soup.find_all('span', class_ = 'product-strike')
        for c in mrp:
            original_price.append(float(c.text.strip('Rs. ')))
    except AttributeError:
        original_price.append(None)
        
    missing_counts = len(brands) - len(original_price)
    if missing_counts > 0:
        original_price.extend([None]*missing_counts)
    
    #description
    try:
        des = soup.find_all('h4', class_='product-product')
        description.extend([i.text for i in des])
    except AttributeError:
        description =' '
        
    #product url

    try:
        li_elements = soup.find_all('li', class_="product-base")
        for d in li_elements:
            a_elements = d.find_all('a', {'data-refreshpage': 'true', 'target': '_blank'})
            for a in a_elements:
                href = 'http://myntra.com/' + a['href']
                product_url.append(href)
    except AttributeError:
        product_url=' '
driver.close()
# Out:
# enter your search term:  dresses
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[2], line 19
#      16 for i in range(1, 300):
#      17     driver.get(search_url(org_url, i))
# ---> 19     soup = BeautifulSoup(driver.page_source, 'html.parser')
#      21     try:
#      22         brand = soup.find_all('h3', class_="product-brand")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:570, in WebDriver.page_source(self)
#     562 @property
#     563 def page_source(self) -> str:
#     564     """Gets the source of the current page.
#     565
#     566     Example:
#     567     --------
#     568     >>> print(driver.page_source)
#     569     """
# --> 570     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response["value"] = self._unwrap_value(response.get("value", None))
#     431     return response
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=136.0.7103.114)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF636F3CF65+75717]
# 	GetHandleVerifier [0x00007FF636F3CFC0+75808]
# 	(No symbol) [0x00007FF636D08F9A]
# 	(No symbol) [0x00007FF636CE1B41]
# 	(No symbol) [0x00007FF636D8EC2E]
# 	(No symbol) [0x00007FF636DAECC2]
# 	(No symbol) [0x00007FF636D87153]
# 	(No symbol) [0x00007FF636D50421]
# 	(No symbol) [0x00007FF636D511B3]
# 	GetHandleVerifier [0x00007FF63723D74D+3223469]
# 	GetHandleVerifier [0x00007FF637237CF2+3200338]
# 	GetHandleVerifier [0x00007FF637255B23+3322755]
# 	GetHandleVerifier [0x00007FF636F56A3A+180890]
# 	GetHandleVerifier [0x00007FF636F5E13F+211359]
# 	GetHandleVerifier [0x00007FF636F452B4+109332]
# 	GetHandleVerifier [0x00007FF636F45462+109762]
# 	GetHandleVerifier [0x00007FF636F2BA79+4825]
# 	BaseThreadInitThunk [0x00007FFB587D7374+20]
# 	RtlUserThreadStart [0x00007FFB5A7DCC91+33]

# %%
df = pd.DataFrame(columns=['brand_name','price','original_price','description','product_url'])
df['brand_name'] = brands
df['price']=price
df['original_price']=original_price
df['description']=description
df['product_url']=product_url

# %%
df
# Out:
#               brand_name   price  original_price  \
# 0               glitchez   329.0           999.0
# 1        U.S. Polo Assn.  1234.0          1899.0
# 2                  A & Y   399.0           999.0
# 3                    Y&I   736.0          1990.0
# 4               STELLERS   319.0           999.0
# ...                  ...     ...             ...
# 14895            HELLCAT   499.0          3897.0
# 14896           Bewakoof   549.0          1549.0
# 14897  French Connection   474.0          1899.0
# 14898          Crocodile   399.0           599.0
# 14899           Adimanav     NaN             NaN
#
#                           description  \
# 0            Relaxed Drip Fit T-shirt
# 1      Men Polo Collar Cotton T-shirt
# 2          Printed Round Neck T-Shirt
# 3      Men Typography Printed T-shirt
# 4            Boys Polo Collar T-shirt
# ...                               ...
# 14895   Boys Pack Of 3 Cotton T-shirt
# 14896    Women Printed Cotton T-shirt
# 14897     Printed Pure Cotton T-shirt
# 14898    Polo Collar Slim Fit T-shirt
# 14899      Unisex Kids Cotton T-shirt
#
#                                              product_url
# 0      http://myntra.com/tshirts/glitchez/glitchez-pu...
# 1      http://myntra.com/tshirts/u.s.+polo+assn./us-p...
# 2      http://myntra.com/tshirts/a+%26+y/a--y-women-p...
# 3      http://myntra.com/tshirts/y%26i/yi-men-typogra...
# 4      http://myntra.com/tshirts/stellers/stellers-bo...
# ...                                                  ...
# 14895  http://myntra.com/tshirts/hellcat/hellcat-boys...
# 14896  http://myntra.com/tshirts/bewakoof/bewakoof-wo...
# 14897  http://myntra.com/tshirts/french+connection/fr...
# 14898  http://myntra.com/tshirts/crocodile/crocodile-...
# 14899  http://myntra.com/tshirts/adimanav/adimanav-un...
#
# [14900 rows x 5 columns]

# %%
print(len(df))
# Out:
# 14900

# %%
df.to_csv('myntra_products_Dresses(2).csv')

# %%
df['brand_name'].nunique()
# Out:
# 524

# %%
df['brand_name'].unique()
# Out:
# array(['glitchez', 'U.S. Polo Assn.', 'A & Y', 'Y&I', 'STELLERS',
#        'United Colors of Benetton', 'RARE RABBIT', 'RARE ONES', 'Puma',
#        'HELLCAT', 'PUMA Motorsport', 'Reebok', 'Bewakoof', 'Crazymonk',
#        'YK X Minute Mirth', 'Allen Solly Junior', 'Crocodile', 'SZN',
#        'Tommy Hilfiger', 'Roadster', 'H&M', 'Pepe Jeans', 'Fabflee',
#        'HIGHLANDER', 'DAMENSCH', 'YK Disney', 'BAESD', 'Leotude',
#        'Nap Chief', 'Tokyo Talkies', 'The Souled Store', 'Googo Gaaga',
#        'Pantaloons Junior', 'Dennis Lingo', 'Nike',
#        'HRX by Hrithik Roshan', 'Jack & Jones', 'Anthrilo',
#        'Mast & Harbour', 'Flying Machine', 'CORSICA', 'Powerlook',
#        'MASCLN SASSAFRAS', 'Van Heusen', 'Dreamz by Pantaloons',
#        'Aero Armour', 'Maniac', 'Marks & Spencer', 'Enamor', 'YK Marvel',
#        'Nautica', 'The Dry State', 'DILLINGER', 'Rigo', 'Pantaloons Baby',
#        'ADRO', 'Difference of Opinion', 'Wear Your Opinion', 'Jockey',
#        'VeBNoR', 'Kook N Keech', 'Status Quo', 'MARVEL STREET',
#        'Chemistry', 'Kook N Keech Teens', 'TheBTclub', 'Moda Rapido',
#        'COLOR CAPITAL', 'Being Human', 'Levis', 'appulse', 'Minicult',
#        'Clovia', 'MANGO', 'PRONK', 'KAJARU', 'Lil Tomatoes', 'StyleCast',
#        'Lux Cozi', 'Sztori', 'Duke', 'Bushirt', 'Aeropostale',
#        'CLAFOUTIS', 'Kids Ville', 'Kotty', 'DressBerry', 'FCUK',
#        'HERE&NOW', 'max', 'NUSYL', 'Fleximaa', 'Kalenji By Decathlon',
#        'Bewakoof AIR', 'VEIRDO', 'YK X Tinyo', 'Mango Kids', 'Genzy',
#        'SPUNKIES', 'Candyskin', 'YUV', 'WROGN', 'BonOrganik', 'IN Love',
#        'Kook N Keech Disney', 'V-Mart', 'The Indian Garage Co',
#        'encore by INVICTUS', 'U.S. Polo Assn. Kids', 'BULLMER',
#        'JUNEBERRY', 'Kryptic', 'CULT', 'Bewakoof Plus', 'KOTTY Basics',
#        'LOCAVESTIR', 'SPYKAR', 'SOLOGNAC By Decathlon', 'Stylo Bug',
#        'KiddoPanti', 'her by invictus', 'LoveDky', 'Athena Immutable',
#        'LUX NITRO', 'THE BEAR HOUSE', 'MuscleBlaze', 'Cherry Crumble',
#        'Manlino', 'XYXX', 'INVICTUS', 'Alan Jones', 'Funday Fashion',
#        'YK', 'KAIDO', 'NOBERO', 'KNITROOT', 'Fame Forever by Lifestyle',
#        'Campus Sutra', 'CELSIUS', 'U.S. Polo Assn. Denim Co.', 'CHKOKKO',
#        'Allen Solly Woman', 'Urbano Fashion', 'CURVY STREET', 'MINI KLUB',
#        'Harvard', 'Kook N Keech Looney Tunes', 'Technosport', 'Bodycare',
#        'Guugly Wuugly', 'R.Code by The Roadster Life Co.', 'Desi Soota',
#        'all about you', 'Adyavastram', 'Juniors by Babyshop',
#        'Nauti Nati', 'MKH', 'YK X Trampoline', 'Minions by Kook N Keech',
#        'Arvesa', 'THE HOLLANDER', 'Soie', 'Stormborn', 'Allen Solly',
#        'Eteenz', 'Red Tape', 'BONKIDS', 'Cantabil', 'Domyos By Decathlon',
#        'Disney by DressBerry', 'Trendyol', 'STREET 9', 'Happy Faces',
#        'ETC', 'Here&Now X Game Begins', 'Juniors by Lifestyle',
#        'Ed-a-Mamma', 'Kook N Keech Marvel', 'Uniplanet store',
#        'Stylecast X Slyck', 'Lee', 'JUMPCUTS', 'DYCA', 'Colorchakra',
#        'Styli', 'Monte Carlo', 'YK Warner Bros', 'ARRAY', 'rock.it',
#        'SINI MINI', 'DISNEY by Dreambe', 'SAIOM', 'ADIDAS', 'ether',
#        'LOCOMOTIVE', 'DressBerry Curve', 'Elibolz', 'BE AWARA', 'KIABI',
#        'Hoop', 'CODEZ', 'Jack & Jones Junior', 'UMILDO', 'Ducati',
#        'U.S. Polo Assn. Women', 'Dpassion', 'Globus', 'BOMBAE TEES',
#        'AUSK', 'Mr Bowerbird', 'Strong And Brave', 'bebe',
#        'Marvel by Miss and Chief', 'Broke Memers', 'TITTLI', 'plusS',
#        'MACK JONNEY', 'KATE & OSCAR', 'mothercare', 'earth conscious',
#        'RASPY', 'Polka Tots', 'SCATCHITE', 'Dagcros', 'MANGO MAN',
#        'Snitch', 'DOOR74', 'Slazenger', 'Gini and Jony', 'Provogue',
#        'SMARTEES', 'Disney By Miss and Chief', 'FLYIND VOGUE OUTFIT',
#        'KUCHIPOO', 'Bene Kleed', 'Kanvin', 'DeFacto', 'SASSAFRAS',
#        'Nottie Planet', 'YOUMAA', 'BOLDFIT', 'Naughty Ninos', '3PIN',
#        'Blackberrys', 'Alcis', 'Ajile by Pantaloons',
#        'Street By Tokyo Talkies', 'Park Avenue',
#        'TOM AND JERRY by Dreambe', 'Powerpuff Girls by Kook N Keech',
#        'Ginger by Lifestyle', 'MORSE CODE', 'RG BY S.S. Clothing',
#        'StyleCast x Revolte', 'Toddylon', 'Louis Philippe Jeans',
#        'Friskers', 'PERFKT-U', 'TRAQUILA', 'Honey by Pantaloons',
#        'THE BEETEL HOUSE', 'Kiddeo', 'Bewakoof Heavy Duty', 'ONE SKY',
#        'Vero Moda', 'Bonkers Corner', 'Crimsoune Club', 'Peter England',
#        'WROGN YOUTH', 'STREET 9 BASICS', 'Young Urban',
#        'Berrylush BASICS', 'French Connection', 'FREECULTR', 'TYKUN',
#        'playR', 'boohooMAN', 'M&H Easy', 'Stylecast X Hersheinbox',
#        'UnderJeans by Spykar', 'Fashion2wear', 'ATHLISIS', 'My Swag',
#        'VERO AMORE', 'ATICX', 'Miss & Chief', 'SLOWLORIS', 'NEXT',
#        'Blissclub', 'Mufti', 'Triumph', 'ALAKH HUB', 'Crazybee Tshirt',
#        'Lagashi', 'Skidlers', 'TOGS & TERRE', 'kintu parantu',
#        'bigbanana', 'Beyoung', 'MISCHIEF MONKEY', 'BUFFARO',
#        'Free Authority', 'edheads', 'Kook N Keech Toons', 'RAYACLOSET',
#        'BUMZEE', 'Arrow', 'Backbenchers', 'Kook N Keech Harry Potter',
#        'FUAARK', 'Zigo', 'Kipsta By Decathlon', 'Bombay High', 'GRACIT',
#        'BROWN BROTHERS', 'BDSQUARE', 'Indian Terrain', 'madfrog',
#        'White Moon', 'Honey Curvytude by Pantaloons', 'Arrow Sport',
#        'PIVL', 'BYFORD by Pantaloons', 'ONLY', 'Metronaut', 'WOOSTRO',
#        'VOLTEDGE', 'Celio', 'London Hills', 'Hypernation', 'HOMEGROWN',
#        'Kushi Flyer', 'GLOBAL NOMAD', 'Oxolloxo', 'Ginie', 'putsum',
#        'beebelle', 'Besick', 'Tromko', 'Kalt', 'MINT STREET', 'FALTU.CO',
#        'Kappa', 'House of Koala', 'CUPID', 'Hive91', 'SASSAFRAS BASICS',
#        'Thomas Scott', 'Huetrap', 'Black Panther', 'nostrum',
#        'TWIN BIRDS', 'Cutiekins', 'Obaan', 'FUNKY MONKEY', 'FITINC',
#        'ROARERS', 'Dollar', 'Outzidr', 'FIFTY TWO', 'People', 'Dreambe',
#        'Trend Level', 'PROTEENS', 'Flingr', 'Inesis By Decathlon',
#        'Slenor', 'BEOM', 'Coolsters by Pantaloons', 'Van Heusen Flex',
#        'BEAST CRICKET', 'RISS', 'OGEN', 'ONN', 'Turtle',
#        'Kook N Keech Batman', 'BRATMA', 'SUPERVEK', 'GAB', 'LYRA',
#        'Club York', 'MYO2', 'Invincible', 'AMERICAN EAGLE OUTFITTERS',
#        'Marvel by Wear Your Mind', 'IUGA', 'Dzant', 'Martini', 'EPPE',
#        'Bodycare Kids', 'Organic Chics', 'AUSTIVO', 'Hang and wear',
#        'BE POSITIVE', 'U&F Beyond', 'Viral trend', 'GIORDANO', 'Parona',
#        'GET GOLF', 'INDISSH', 'Wrangler', 'AAHWAN', 'MYEONN',
#        'MASTI TEES', 'SG', 'AD By Arvind', 'BUY NEW TREND',
#        'THEFITTHEORY', 'FILA', 'BLUEFICUS', 'PWTI', 'Juliet', 'TINIBERRY',
#        'PLUM TREE', 'WILD ELEPHANT', 'LUX PARKER', 'FBAR', 'CAPTCHA',
#        'Dogman', 'SPORTO', 'BEAT LONDON by PEPE JEANS', 'Shiv Naresh',
#        '20Dresses', 'REYA', 'Genoa', 'Quechua By Decathlon', 'MAXZONE',
#        'Artengo By Decathlon', 'SillyBoom', 'Freeform by High Star',
#        'UNRL', 'COBB', 'Rodzen', 'CODE by Lifestyle', 'Parx', 'DDOUDDOU',
#        'Pierre Carlo', 'Ed-a-Mamma Baby', 'Adimanav', 'FUGAZEE',
#        'LOUIS STITCH', 'NEVER LOSE', 'DIMPY GARMENTS', 'Octave',
#        'CLAPTON', 'DIDA', 'BODYACTIVE', 'SF JEANS by Pantaloons',
#        'Black Collection', 'BLUSHES', 'angloindu', '98 Degree North',
#        'Force NXT', 'KAY DEE', 'Espresso', 'ZEFFIT', 'Gavin Paris',
#        'Harry Potter by Wear Your Mind', 'MANTICORE', 'Antiloop', 'KETCH',
#        'x2o', 'DC by Kook N Keech', 'QUCO', 'Edyssa', 'Wildcraft',
#        'Klub Fox', 'RELANE', 'Polo Plus', 'SWAGNOX', 'KASMA', 'Jinfo',
#        'Wear Your Mind', 'mackly', 'ARMISTO', 'Campana', 'SQUIREHOOD',
#        'LAUREN ADAMS', 'f Gallery', 'SIX5SIX', 'URBANICE', 'STARFOX',
#        'WATAY', 'Amante', 'ELLE', 'MODARUE', 'FEMEA', 'Kiddiekid',
#        'MOUNTAIN COLOURS', 'Tantra', 'FROSEN FOX', 'GEE 5', 'zebu',
#        'DIXCY SCOTT', 'Urbano Plus', 'Louis Bayrad', 'PAUL STREET',
#        'Basics', 'DOMIN8', 'Nun', 'Harpa', 'DressBerry Basics',
#        'Markle Moro', 'TRENDY RABBIT', 'Instafab Plus', 'SMAN',
#        'Mad Over Print', 'Duchess', 'WILD COPS', 'STATUS MANTRA',
#        'Basics By Tokyo Talkies', 'Xenovaurban', 'MADSTO', 'CHKOKKO Plus',
#        'THE MILLION CLUB', '3Colors', 'Kook N Keech Star Wars', 'MiArcus',
#        'KIPRUN By Decathlon', 'PILOLO', 'Lounge Dreams', 'PUELLA',
#        'Ajolli', 'Adobe'], dtype=object)
